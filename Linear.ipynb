# %%
import torch
print(torch.__version__)
print('gpu:',torch.cuda.is_available())
# Out:
# 1.1.0
# gpu: True

# %%
import torch
import torch.nn as nn
# 生成实验数据
data = torch.ones(100,2)
xa = torch.normal(2*data, 1)
xb = torch.normal(-2*data, 1)
ya = torch.zeros(100)
yb = torch.ones(100)
x = torch.cat((xa,xb),0)
y = torch.cat((ya,yb),0)

# 模型参数
epochs = 500
learning_rate = 0.01

# %%
class LR(nn.Module):
    def __init__(self):
        super(LR, self).__init__()
        self.linear = nn.Linear(2,1)
        self.sigmoid = nn.Sigmoid()
    
    def forward(self, x):
        return self.sigmoid(self.linear(x))

model = LR()

criterion = nn.BCELoss()
optimizer = torch.optim.SGD(model.parameters(), lr=learning_rate)

for epoch in range(epochs):
    optimizer.zero_grad()
    loss = criterion(model(x), y)
    print(epoch, loss)
    loss.backward()
    optimizer.step()
# Out:
# 0 tensor(0.6432, grad_fn=<BinaryCrossEntropyBackward>)
# 1 tensor(0.6250, grad_fn=<BinaryCrossEntropyBackward>)
# 2 tensor(0.6075, grad_fn=<BinaryCrossEntropyBackward>)
# 3 tensor(0.5909, grad_fn=<BinaryCrossEntropyBackward>)
# 4 tensor(0.5749, grad_fn=<BinaryCrossEntropyBackward>)
# 5 tensor(0.5597, grad_fn=<BinaryCrossEntropyBackward>)
# 6 tensor(0.5451, grad_fn=<BinaryCrossEntropyBackward>)
# 7 tensor(0.5311, grad_fn=<BinaryCrossEntropyBackward>)
# 8 tensor(0.5177, grad_fn=<BinaryCrossEntropyBackward>)
# 9 tensor(0.5049, grad_fn=<BinaryCrossEntropyBackward>)
# 10 tensor(0.4926, grad_fn=<BinaryCrossEntropyBackward>)
# 11 tensor(0.4808, grad_fn=<BinaryCrossEntropyBackward>)
# 12 tensor(0.4695, grad_fn=<BinaryCrossEntropyBackward>)
# 13 tensor(0.4586, grad_fn=<BinaryCrossEntropyBackward>)
# 14 tensor(0.4482, grad_fn=<BinaryCrossEntropyBackward>)
# 15 tensor(0.4382, grad_fn=<BinaryCrossEntropyBackward>)
# 16 tensor(0.4286, grad_fn=<BinaryCrossEntropyBackward>)
# 17 tensor(0.4194, grad_fn=<BinaryCrossEntropyBackward>)
# 18 tensor(0.4105, grad_fn=<BinaryCrossEntropyBackward>)
# 19 tensor(0.4019, grad_fn=<BinaryCrossEntropyBackward>)
# 20 tensor(0.3937, grad_fn=<BinaryCrossEntropyBackward>)
# 21 tensor(0.3858, grad_fn=<BinaryCrossEntropyBackward>)
# 22 tensor(0.3781, grad_fn=<BinaryCrossEntropyBackward>)
# 23 tensor(0.3708, grad_fn=<BinaryCrossEntropyBackward>)
# 24 tensor(0.3637, grad_fn=<BinaryCrossEntropyBackward>)
# 25 tensor(0.3568, grad_fn=<BinaryCrossEntropyBackward>)
# 26 tensor(0.3502, grad_fn=<BinaryCrossEntropyBackward>)
# 27 tensor(0.3438, grad_fn=<BinaryCrossEntropyBackward>)
# 28 tensor(0.3377, grad_fn=<BinaryCrossEntropyBackward>)
# 29 tensor(0.3317, grad_fn=<BinaryCrossEntropyBackward>)
# 30 tensor(0.3260, grad_fn=<BinaryCrossEntropyBackward>)
# 31 tensor(0.3204, grad_fn=<BinaryCrossEntropyBackward>)
# 32 tensor(0.3150, grad_fn=<BinaryCrossEntropyBackward>)
# 33 tensor(0.3098, grad_fn=<BinaryCrossEntropyBackward>)
# 34 tensor(0.3047, grad_fn=<BinaryCrossEntropyBackward>)
# 35 tensor(0.2998, grad_fn=<BinaryCrossEntropyBackward>)
# 36 tensor(0.2951, grad_fn=<BinaryCrossEntropyBackward>)
# 37 tensor(0.2905, grad_fn=<BinaryCrossEntropyBackward>)
# 38 tensor(0.2860, grad_fn=<BinaryCrossEntropyBackward>)
# 39 tensor(0.2817, grad_fn=<BinaryCrossEntropyBackward>)
# 40 tensor(0.2775, grad_fn=<BinaryCrossEntropyBackward>)
# 41 tensor(0.2734, grad_fn=<BinaryCrossEntropyBackward>)
# 42 tensor(0.2695, grad_fn=<BinaryCrossEntropyBackward>)
# 43 tensor(0.2656, grad_fn=<BinaryCrossEntropyBackward>)
# 44 tensor(0.2619, grad_fn=<BinaryCrossEntropyBackward>)
# 45 tensor(0.2582, grad_fn=<BinaryCrossEntropyBackward>)
# 46 tensor(0.2547, grad_fn=<BinaryCrossEntropyBackward>)
# 47 tensor(0.2513, grad_fn=<BinaryCrossEntropyBackward>)
# 48 tensor(0.2479, grad_fn=<BinaryCrossEntropyBackward>)
# 49 tensor(0.2447, grad_fn=<BinaryCrossEntropyBackward>)
# 50 tensor(0.2415, grad_fn=<BinaryCrossEntropyBackward>)
# 51 tensor(0.2384, grad_fn=<BinaryCrossEntropyBackward>)
# 52 tensor(0.2354, grad_fn=<BinaryCrossEntropyBackward>)
# 53 tensor(0.2324, grad_fn=<BinaryCrossEntropyBackward>)
# 54 tensor(0.2296, grad_fn=<BinaryCrossEntropyBackward>)
# 55 tensor(0.2268, grad_fn=<BinaryCrossEntropyBackward>)
# 56 tensor(0.2241, grad_fn=<BinaryCrossEntropyBackward>)
# 57 tensor(0.2214, grad_fn=<BinaryCrossEntropyBackward>)
# 58 tensor(0.2188, grad_fn=<BinaryCrossEntropyBackward>)
# 59 tensor(0.2163, grad_fn=<BinaryCrossEntropyBackward>)
# 60 tensor(0.2138, grad_fn=<BinaryCrossEntropyBackward>)
# 61 tensor(0.2114, grad_fn=<BinaryCrossEntropyBackward>)
# 62 tensor(0.2090, grad_fn=<BinaryCrossEntropyBackward>)
# 63 tensor(0.2067, grad_fn=<BinaryCrossEntropyBackward>)
# 64 tensor(0.2045, grad_fn=<BinaryCrossEntropyBackward>)
# 65 tensor(0.2023, grad_fn=<BinaryCrossEntropyBackward>)
# 66 tensor(0.2001, grad_fn=<BinaryCrossEntropyBackward>)
# 67 tensor(0.1980, grad_fn=<BinaryCrossEntropyBackward>)
# 68 tensor(0.1959, grad_fn=<BinaryCrossEntropyBackward>)
# 69 tensor(0.1939, grad_fn=<BinaryCrossEntropyBackward>)
# 70 tensor(0.1919, grad_fn=<BinaryCrossEntropyBackward>)
# 71 tensor(0.1900, grad_fn=<BinaryCrossEntropyBackward>)
# 72 tensor(0.1881, grad_fn=<BinaryCrossEntropyBackward>)
# 73 tensor(0.1863, grad_fn=<BinaryCrossEntropyBackward>)
# 74 tensor(0.1844, grad_fn=<BinaryCrossEntropyBackward>)
# 75 tensor(0.1827, grad_fn=<BinaryCrossEntropyBackward>)
# 76 tensor(0.1809, grad_fn=<BinaryCrossEntropyBackward>)
# 77 tensor(0.1792, grad_fn=<BinaryCrossEntropyBackward>)
# 78 tensor(0.1775, grad_fn=<BinaryCrossEntropyBackward>)
# 79 tensor(0.1759, grad_fn=<BinaryCrossEntropyBackward>)
# 80 tensor(0.1743, grad_fn=<BinaryCrossEntropyBackward>)
# 81 tensor(0.1727, grad_fn=<BinaryCrossEntropyBackward>)
# 82 tensor(0.1711, grad_fn=<BinaryCrossEntropyBackward>)
# 83 tensor(0.1696, grad_fn=<BinaryCrossEntropyBackward>)
# 84 tensor(0.1681, grad_fn=<BinaryCrossEntropyBackward>)
# 85 tensor(0.1667, grad_fn=<BinaryCrossEntropyBackward>)
# 86 tensor(0.1652, grad_fn=<BinaryCrossEntropyBackward>)
# 87 tensor(0.1638, grad_fn=<BinaryCrossEntropyBackward>)
# 88 tensor(0.1624, grad_fn=<BinaryCrossEntropyBackward>)
# 89 tensor(0.1611, grad_fn=<BinaryCrossEntropyBackward>)
# 90 tensor(0.1597, grad_fn=<BinaryCrossEntropyBackward>)
# 91 tensor(0.1584, grad_fn=<BinaryCrossEntropyBackward>)
# 92 tensor(0.1571, grad_fn=<BinaryCrossEntropyBackward>)
# 93 tensor(0.1559, grad_fn=<BinaryCrossEntropyBackward>)
# 94 tensor(0.1546, grad_fn=<BinaryCrossEntropyBackward>)
# 95 tensor(0.1534, grad_fn=<BinaryCrossEntropyBackward>)
# 96 tensor(0.1522, grad_fn=<BinaryCrossEntropyBackward>)
# 97 tensor(0.1510, grad_fn=<BinaryCrossEntropyBackward>)
# 98 tensor(0.1498, grad_fn=<BinaryCrossEntropyBackward>)
# 99 tensor(0.1487, grad_fn=<BinaryCrossEntropyBackward>)
# 100 tensor(0.1476, grad_fn=<BinaryCrossEntropyBackward>)
# 101 tensor(0.1464, grad_fn=<BinaryCrossEntropyBackward>)
# 102 tensor(0.1454, grad_fn=<BinaryCrossEntropyBackward>)
# 103 tensor(0.1443, grad_fn=<BinaryCrossEntropyBackward>)
# 104 tensor(0.1432, grad_fn=<BinaryCrossEntropyBackward>)
# 105 tensor(0.1422, grad_fn=<BinaryCrossEntropyBackward>)
# 106 tensor(0.1412, grad_fn=<BinaryCrossEntropyBackward>)
# 107 tensor(0.1401, grad_fn=<BinaryCrossEntropyBackward>)
# 108 tensor(0.1392, grad_fn=<BinaryCrossEntropyBackward>)
# 109 tensor(0.1382, grad_fn=<BinaryCrossEntropyBackward>)
# 110 tensor(0.1372, grad_fn=<BinaryCrossEntropyBackward>)
# 111 tensor(0.1363, grad_fn=<BinaryCrossEntropyBackward>)
# 112 tensor(0.1353, grad_fn=<BinaryCrossEntropyBackward>)
# 113 tensor(0.1344, grad_fn=<BinaryCrossEntropyBackward>)
# 114 tensor(0.1335, grad_fn=<BinaryCrossEntropyBackward>)
# 115 tensor(0.1326, grad_fn=<BinaryCrossEntropyBackward>)
# 116 tensor(0.1317, grad_fn=<BinaryCrossEntropyBackward>)
# 117 tensor(0.1309, grad_fn=<BinaryCrossEntropyBackward>)
# 118 tensor(0.1300, grad_fn=<BinaryCrossEntropyBackward>)
# 119 tensor(0.1292, grad_fn=<BinaryCrossEntropyBackward>)
# 120 tensor(0.1283, grad_fn=<BinaryCrossEntropyBackward>)
# 121 tensor(0.1275, grad_fn=<BinaryCrossEntropyBackward>)
# 122 tensor(0.1267, grad_fn=<BinaryCrossEntropyBackward>)
# 123 tensor(0.1259, grad_fn=<BinaryCrossEntropyBackward>)
# 124 tensor(0.1251, grad_fn=<BinaryCrossEntropyBackward>)
# 125 tensor(0.1243, grad_fn=<BinaryCrossEntropyBackward>)
# 126 tensor(0.1236, grad_fn=<BinaryCrossEntropyBackward>)
# 127 tensor(0.1228, grad_fn=<BinaryCrossEntropyBackward>)
# 128 tensor(0.1221, grad_fn=<BinaryCrossEntropyBackward>)
# 129 tensor(0.1213, grad_fn=<BinaryCrossEntropyBackward>)
# 130 tensor(0.1206, grad_fn=<BinaryCrossEntropyBackward>)
# 131 tensor(0.1199, grad_fn=<BinaryCrossEntropyBackward>)
# 132 tensor(0.1192, grad_fn=<BinaryCrossEntropyBackward>)
# 133 tensor(0.1185, grad_fn=<BinaryCrossEntropyBackward>)
# 134 tensor(0.1178, grad_fn=<BinaryCrossEntropyBackward>)
# 135 tensor(0.1171, grad_fn=<BinaryCrossEntropyBackward>)
# 136 tensor(0.1164, grad_fn=<BinaryCrossEntropyBackward>)
# 137 tensor(0.1158, grad_fn=<BinaryCrossEntropyBackward>)
# 138 tensor(0.1151, grad_fn=<BinaryCrossEntropyBackward>)
# 139 tensor(0.1145, grad_fn=<BinaryCrossEntropyBackward>)
# 140 tensor(0.1138, grad_fn=<BinaryCrossEntropyBackward>)
# 141 tensor(0.1132, grad_fn=<BinaryCrossEntropyBackward>)
# 142 tensor(0.1126, grad_fn=<BinaryCrossEntropyBackward>)
# 143 tensor(0.1120, grad_fn=<BinaryCrossEntropyBackward>)
# 144 tensor(0.1114, grad_fn=<BinaryCrossEntropyBackward>)
# 145 tensor(0.1108, grad_fn=<BinaryCrossEntropyBackward>)
# 146 tensor(0.1102, grad_fn=<BinaryCrossEntropyBackward>)
# 147 tensor(0.1096, grad_fn=<BinaryCrossEntropyBackward>)
# 148 tensor(0.1090, grad_fn=<BinaryCrossEntropyBackward>)
# 149 tensor(0.1084, grad_fn=<BinaryCrossEntropyBackward>)
# 150 tensor(0.1079, grad_fn=<BinaryCrossEntropyBackward>)
# 151 tensor(0.1073, grad_fn=<BinaryCrossEntropyBackward>)
# 152 tensor(0.1067, grad_fn=<BinaryCrossEntropyBackward>)
# 153 tensor(0.1062, grad_fn=<BinaryCrossEntropyBackward>)
# 154 tensor(0.1057, grad_fn=<BinaryCrossEntropyBackward>)
# 155 tensor(0.1051, grad_fn=<BinaryCrossEntropyBackward>)
# 156 tensor(0.1046, grad_fn=<BinaryCrossEntropyBackward>)
# 157 tensor(0.1041, grad_fn=<BinaryCrossEntropyBackward>)
# 158 tensor(0.1036, grad_fn=<BinaryCrossEntropyBackward>)
# 159 tensor(0.1030, grad_fn=<BinaryCrossEntropyBackward>)
# 160 tensor(0.1025, grad_fn=<BinaryCrossEntropyBackward>)
# 161 tensor(0.1020, grad_fn=<BinaryCrossEntropyBackward>)
# 162 tensor(0.1015, grad_fn=<BinaryCrossEntropyBackward>)
# 163 tensor(0.1010, grad_fn=<BinaryCrossEntropyBackward>)
# 164 tensor(0.1006, grad_fn=<BinaryCrossEntropyBackward>)
# 165 tensor(0.1001, grad_fn=<BinaryCrossEntropyBackward>)
# 166 tensor(0.0996, grad_fn=<BinaryCrossEntropyBackward>)
# 167 tensor(0.0991, grad_fn=<BinaryCrossEntropyBackward>)
# 168 tensor(0.0987, grad_fn=<BinaryCrossEntropyBackward>)
# 169 tensor(0.0982, grad_fn=<BinaryCrossEntropyBackward>)
# 170 tensor(0.0978, grad_fn=<BinaryCrossEntropyBackward>)
# 171 tensor(0.0973, grad_fn=<BinaryCrossEntropyBackward>)
# 172 tensor(0.0969, grad_fn=<BinaryCrossEntropyBackward>)
# 173 tensor(0.0964, grad_fn=<BinaryCrossEntropyBackward>)
# 174 tensor(0.0960, grad_fn=<BinaryCrossEntropyBackward>)
# 175 tensor(0.0956, grad_fn=<BinaryCrossEntropyBackward>)
# 176 tensor(0.0951, grad_fn=<BinaryCrossEntropyBackward>)
# 177 tensor(0.0947, grad_fn=<BinaryCrossEntropyBackward>)
# 178 tensor(0.0943, grad_fn=<BinaryCrossEntropyBackward>)
# 179 tensor(0.0939, grad_fn=<BinaryCrossEntropyBackward>)
# 180 tensor(0.0935, grad_fn=<BinaryCrossEntropyBackward>)
# 181 tensor(0.0931, grad_fn=<BinaryCrossEntropyBackward>)
# 182 tensor(0.0926, grad_fn=<BinaryCrossEntropyBackward>)
# 183 tensor(0.0923, grad_fn=<BinaryCrossEntropyBackward>)
# 184 tensor(0.0919, grad_fn=<BinaryCrossEntropyBackward>)
# 185 tensor(0.0915, grad_fn=<BinaryCrossEntropyBackward>)
# 186 tensor(0.0911, grad_fn=<BinaryCrossEntropyBackward>)
# 187 tensor(0.0907, grad_fn=<BinaryCrossEntropyBackward>)
# 188 tensor(0.0903, grad_fn=<BinaryCrossEntropyBackward>)
# 189 tensor(0.0899, grad_fn=<BinaryCrossEntropyBackward>)
# 190 tensor(0.0896, grad_fn=<BinaryCrossEntropyBackward>)
# 191 tensor(0.0892, grad_fn=<BinaryCrossEntropyBackward>)
# 192 tensor(0.0888, grad_fn=<BinaryCrossEntropyBackward>)
# 193 tensor(0.0885, grad_fn=<BinaryCrossEntropyBackward>)
# 194 tensor(0.0881, grad_fn=<BinaryCrossEntropyBackward>)
# 195 tensor(0.0877, grad_fn=<BinaryCrossEntropyBackward>)
# 196 tensor(0.0874, grad_fn=<BinaryCrossEntropyBackward>)
# 197 tensor(0.0870, grad_fn=<BinaryCrossEntropyBackward>)
# 198 tensor(0.0867, grad_fn=<BinaryCrossEntropyBackward>)
# 199 tensor(0.0864, grad_fn=<BinaryCrossEntropyBackward>)
# 200 tensor(0.0860, grad_fn=<BinaryCrossEntropyBackward>)
# 201 tensor(0.0857, grad_fn=<BinaryCrossEntropyBackward>)
# 202 tensor(0.0853, grad_fn=<BinaryCrossEntropyBackward>)
# 203 tensor(0.0850, grad_fn=<BinaryCrossEntropyBackward>)
# 204 tensor(0.0847, grad_fn=<BinaryCrossEntropyBackward>)
# 205 tensor(0.0844, grad_fn=<BinaryCrossEntropyBackward>)
# 206 tensor(0.0840, grad_fn=<BinaryCrossEntropyBackward>)
# 207 tensor(0.0837, grad_fn=<BinaryCrossEntropyBackward>)
# 208 tensor(0.0834, grad_fn=<BinaryCrossEntropyBackward>)
# 209 tensor(0.0831, grad_fn=<BinaryCrossEntropyBackward>)
# 210 tensor(0.0828, grad_fn=<BinaryCrossEntropyBackward>)
# 211 tensor(0.0825, grad_fn=<BinaryCrossEntropyBackward>)
# 212 tensor(0.0822, grad_fn=<BinaryCrossEntropyBackward>)
# 213 tensor(0.0818, grad_fn=<BinaryCrossEntropyBackward>)
# 214 tensor(0.0815, grad_fn=<BinaryCrossEntropyBackward>)
# 215 tensor(0.0812, grad_fn=<BinaryCrossEntropyBackward>)
# 216 tensor(0.0809, grad_fn=<BinaryCrossEntropyBackward>)
# 217 tensor(0.0807, grad_fn=<BinaryCrossEntropyBackward>)
# 218 tensor(0.0804, grad_fn=<BinaryCrossEntropyBackward>)
# 219 tensor(0.0801, grad_fn=<BinaryCrossEntropyBackward>)
# 220 tensor(0.0798, grad_fn=<BinaryCrossEntropyBackward>)
# 221 tensor(0.0795, grad_fn=<BinaryCrossEntropyBackward>)
# 222 tensor(0.0792, grad_fn=<BinaryCrossEntropyBackward>)
# 223 tensor(0.0789, grad_fn=<BinaryCrossEntropyBackward>)
# 224 tensor(0.0787, grad_fn=<BinaryCrossEntropyBackward>)
# 225 tensor(0.0784, grad_fn=<BinaryCrossEntropyBackward>)
# 226 tensor(0.0781, grad_fn=<BinaryCrossEntropyBackward>)
# 227 tensor(0.0778, grad_fn=<BinaryCrossEntropyBackward>)
# 228 tensor(0.0776, grad_fn=<BinaryCrossEntropyBackward>)
# 229 tensor(0.0773, grad_fn=<BinaryCrossEntropyBackward>)
# 230 tensor(0.0770, grad_fn=<BinaryCrossEntropyBackward>)
# 231 tensor(0.0768, grad_fn=<BinaryCrossEntropyBackward>)
# 232 tensor(0.0765, grad_fn=<BinaryCrossEntropyBackward>)
# 233 tensor(0.0763, grad_fn=<BinaryCrossEntropyBackward>)
# 234 tensor(0.0760, grad_fn=<BinaryCrossEntropyBackward>)
# 235 tensor(0.0757, grad_fn=<BinaryCrossEntropyBackward>)
# 236 tensor(0.0755, grad_fn=<BinaryCrossEntropyBackward>)
# 237 tensor(0.0752, grad_fn=<BinaryCrossEntropyBackward>)
# 238 tensor(0.0750, grad_fn=<BinaryCrossEntropyBackward>)
# 239 tensor(0.0747, grad_fn=<BinaryCrossEntropyBackward>)
# 240 tensor(0.0745, grad_fn=<BinaryCrossEntropyBackward>)
# 241 tensor(0.0743, grad_fn=<BinaryCrossEntropyBackward>)
# 242 tensor(0.0740, grad_fn=<BinaryCrossEntropyBackward>)
# 243 tensor(0.0738, grad_fn=<BinaryCrossEntropyBackward>)
# 244 tensor(0.0735, grad_fn=<BinaryCrossEntropyBackward>)
# 245 tensor(0.0733, grad_fn=<BinaryCrossEntropyBackward>)
# 246 tensor(0.0731, grad_fn=<BinaryCrossEntropyBackward>)
# 247 tensor(0.0728, grad_fn=<BinaryCrossEntropyBackward>)
# 248 tensor(0.0726, grad_fn=<BinaryCrossEntropyBackward>)
# 249 tensor(0.0724, grad_fn=<BinaryCrossEntropyBackward>)
# 250 tensor(0.0721, grad_fn=<BinaryCrossEntropyBackward>)
# 251 tensor(0.0719, grad_fn=<BinaryCrossEntropyBackward>)
# 252 tensor(0.0717, grad_fn=<BinaryCrossEntropyBackward>)
# 253 tensor(0.0715, grad_fn=<BinaryCrossEntropyBackward>)
# 254 tensor(0.0713, grad_fn=<BinaryCrossEntropyBackward>)
# 255 tensor(0.0710, grad_fn=<BinaryCrossEntropyBackward>)
# 256 tensor(0.0708, grad_fn=<BinaryCrossEntropyBackward>)
# 257 tensor(0.0706, grad_fn=<BinaryCrossEntropyBackward>)
# 258 tensor(0.0704, grad_fn=<BinaryCrossEntropyBackward>)
# 259 tensor(0.0702, grad_fn=<BinaryCrossEntropyBackward>)
# 260 tensor(0.0700, grad_fn=<BinaryCrossEntropyBackward>)
# 261 tensor(0.0697, grad_fn=<BinaryCrossEntropyBackward>)
# 262 tensor(0.0695, grad_fn=<BinaryCrossEntropyBackward>)
# 263 tensor(0.0693, grad_fn=<BinaryCrossEntropyBackward>)
# 264 tensor(0.0691, grad_fn=<BinaryCrossEntropyBackward>)
# 265 tensor(0.0689, grad_fn=<BinaryCrossEntropyBackward>)
# 266 tensor(0.0687, grad_fn=<BinaryCrossEntropyBackward>)
# 267 tensor(0.0685, grad_fn=<BinaryCrossEntropyBackward>)
# 268 tensor(0.0683, grad_fn=<BinaryCrossEntropyBackward>)
# 269 tensor(0.0681, grad_fn=<BinaryCrossEntropyBackward>)
# 270 tensor(0.0679, grad_fn=<BinaryCrossEntropyBackward>)
# 271 tensor(0.0677, grad_fn=<BinaryCrossEntropyBackward>)
# 272 tensor(0.0675, grad_fn=<BinaryCrossEntropyBackward>)
# 273 tensor(0.0673, grad_fn=<BinaryCrossEntropyBackward>)
# 274 tensor(0.0671, grad_fn=<BinaryCrossEntropyBackward>)
# 275 tensor(0.0669, grad_fn=<BinaryCrossEntropyBackward>)
# 276 tensor(0.0668, grad_fn=<BinaryCrossEntropyBackward>)
# 277 tensor(0.0666, grad_fn=<BinaryCrossEntropyBackward>)
# 278 tensor(0.0664, grad_fn=<BinaryCrossEntropyBackward>)
# 279 tensor(0.0662, grad_fn=<BinaryCrossEntropyBackward>)
# 280 tensor(0.0660, grad_fn=<BinaryCrossEntropyBackward>)
# 281 tensor(0.0658, grad_fn=<BinaryCrossEntropyBackward>)
# 282 tensor(0.0656, grad_fn=<BinaryCrossEntropyBackward>)
# 283 tensor(0.0655, grad_fn=<BinaryCrossEntropyBackward>)
# 284 tensor(0.0653, grad_fn=<BinaryCrossEntropyBackward>)
# 285 tensor(0.0651, grad_fn=<BinaryCrossEntropyBackward>)
# 286 tensor(0.0649, grad_fn=<BinaryCrossEntropyBackward>)
# 287 tensor(0.0647, grad_fn=<BinaryCrossEntropyBackward>)
# 288 tensor(0.0646, grad_fn=<BinaryCrossEntropyBackward>)
# 289 tensor(0.0644, grad_fn=<BinaryCrossEntropyBackward>)
# 290 tensor(0.0642, grad_fn=<BinaryCrossEntropyBackward>)
# 291 tensor(0.0640, grad_fn=<BinaryCrossEntropyBackward>)
# 292 tensor(0.0639, grad_fn=<BinaryCrossEntropyBackward>)
# 293 tensor(0.0637, grad_fn=<BinaryCrossEntropyBackward>)
# 294 tensor(0.0635, grad_fn=<BinaryCrossEntropyBackward>)
# 295 tensor(0.0634, grad_fn=<BinaryCrossEntropyBackward>)
# 296 tensor(0.0632, grad_fn=<BinaryCrossEntropyBackward>)
# 297 tensor(0.0630, grad_fn=<BinaryCrossEntropyBackward>)
# 298 tensor(0.0629, grad_fn=<BinaryCrossEntropyBackward>)
# 299 tensor(0.0627, grad_fn=<BinaryCrossEntropyBackward>)
# 300 tensor(0.0625, grad_fn=<BinaryCrossEntropyBackward>)
# 301 tensor(0.0624, grad_fn=<BinaryCrossEntropyBackward>)
# 302 tensor(0.0622, grad_fn=<BinaryCrossEntropyBackward>)
# 303 tensor(0.0620, grad_fn=<BinaryCrossEntropyBackward>)
# 304 tensor(0.0619, grad_fn=<BinaryCrossEntropyBackward>)
# 305 tensor(0.0617, grad_fn=<BinaryCrossEntropyBackward>)
# 306 tensor(0.0616, grad_fn=<BinaryCrossEntropyBackward>)
# 307 tensor(0.0614, grad_fn=<BinaryCrossEntropyBackward>)
# 308 tensor(0.0613, grad_fn=<BinaryCrossEntropyBackward>)
# 309 tensor(0.0611, grad_fn=<BinaryCrossEntropyBackward>)
# 310 tensor(0.0610, grad_fn=<BinaryCrossEntropyBackward>)
# 311 tensor(0.0608, grad_fn=<BinaryCrossEntropyBackward>)
# 312 tensor(0.0606, grad_fn=<BinaryCrossEntropyBackward>)
# 313 tensor(0.0605, grad_fn=<BinaryCrossEntropyBackward>)
# 314 tensor(0.0603, grad_fn=<BinaryCrossEntropyBackward>)
# 315 tensor(0.0602, grad_fn=<BinaryCrossEntropyBackward>)
# 316 tensor(0.0600, grad_fn=<BinaryCrossEntropyBackward>)
# 317 tensor(0.0599, grad_fn=<BinaryCrossEntropyBackward>)
# 318 tensor(0.0598, grad_fn=<BinaryCrossEntropyBackward>)
# 319 tensor(0.0596, grad_fn=<BinaryCrossEntropyBackward>)
# 320 tensor(0.0595, grad_fn=<BinaryCrossEntropyBackward>)
# 321 tensor(0.0593, grad_fn=<BinaryCrossEntropyBackward>)
# 322 tensor(0.0592, grad_fn=<BinaryCrossEntropyBackward>)
# 323 tensor(0.0590, grad_fn=<BinaryCrossEntropyBackward>)
# 324 tensor(0.0589, grad_fn=<BinaryCrossEntropyBackward>)
# 325 tensor(0.0587, grad_fn=<BinaryCrossEntropyBackward>)
# 326 tensor(0.0586, grad_fn=<BinaryCrossEntropyBackward>)
# 327 tensor(0.0585, grad_fn=<BinaryCrossEntropyBackward>)
# 328 tensor(0.0583, grad_fn=<BinaryCrossEntropyBackward>)
# 329 tensor(0.0582, grad_fn=<BinaryCrossEntropyBackward>)
# 330 tensor(0.0581, grad_fn=<BinaryCrossEntropyBackward>)
# 331 tensor(0.0579, grad_fn=<BinaryCrossEntropyBackward>)
# 332 tensor(0.0578, grad_fn=<BinaryCrossEntropyBackward>)
# 333 tensor(0.0576, grad_fn=<BinaryCrossEntropyBackward>)
# 334 tensor(0.0575, grad_fn=<BinaryCrossEntropyBackward>)
# 335 tensor(0.0574, grad_fn=<BinaryCrossEntropyBackward>)
# 336 tensor(0.0572, grad_fn=<BinaryCrossEntropyBackward>)
# 337 tensor(0.0571, grad_fn=<BinaryCrossEntropyBackward>)
# 338 tensor(0.0570, grad_fn=<BinaryCrossEntropyBackward>)
# 339 tensor(0.0568, grad_fn=<BinaryCrossEntropyBackward>)
# 340 tensor(0.0567, grad_fn=<BinaryCrossEntropyBackward>)
# 341 tensor(0.0566, grad_fn=<BinaryCrossEntropyBackward>)
# 342 tensor(0.0565, grad_fn=<BinaryCrossEntropyBackward>)
# 343 tensor(0.0563, grad_fn=<BinaryCrossEntropyBackward>)
# 344 tensor(0.0562, grad_fn=<BinaryCrossEntropyBackward>)
# 345 tensor(0.0561, grad_fn=<BinaryCrossEntropyBackward>)
# 346 tensor(0.0560, grad_fn=<BinaryCrossEntropyBackward>)
# 347 tensor(0.0558, grad_fn=<BinaryCrossEntropyBackward>)
# 348 tensor(0.0557, grad_fn=<BinaryCrossEntropyBackward>)
# 349 tensor(0.0556, grad_fn=<BinaryCrossEntropyBackward>)
# 350 tensor(0.0555, grad_fn=<BinaryCrossEntropyBackward>)
# 351 tensor(0.0553, grad_fn=<BinaryCrossEntropyBackward>)
# 352 tensor(0.0552, grad_fn=<BinaryCrossEntropyBackward>)
# 353 tensor(0.0551, grad_fn=<BinaryCrossEntropyBackward>)
# 354 tensor(0.0550, grad_fn=<BinaryCrossEntropyBackward>)
# 355 tensor(0.0548, grad_fn=<BinaryCrossEntropyBackward>)
# 356 tensor(0.0547, grad_fn=<BinaryCrossEntropyBackward>)
# 357 tensor(0.0546, grad_fn=<BinaryCrossEntropyBackward>)
# 358 tensor(0.0545, grad_fn=<BinaryCrossEntropyBackward>)
# 359 tensor(0.0544, grad_fn=<BinaryCrossEntropyBackward>)
# 360 tensor(0.0543, grad_fn=<BinaryCrossEntropyBackward>)
# 361 tensor(0.0541, grad_fn=<BinaryCrossEntropyBackward>)
# 362 tensor(0.0540, grad_fn=<BinaryCrossEntropyBackward>)
# 363 tensor(0.0539, grad_fn=<BinaryCrossEntropyBackward>)
# 364 tensor(0.0538, grad_fn=<BinaryCrossEntropyBackward>)
# 365 tensor(0.0537, grad_fn=<BinaryCrossEntropyBackward>)
# 366 tensor(0.0536, grad_fn=<BinaryCrossEntropyBackward>)
# 367 tensor(0.0535, grad_fn=<BinaryCrossEntropyBackward>)
# 368 tensor(0.0533, grad_fn=<BinaryCrossEntropyBackward>)
# 369 tensor(0.0532, grad_fn=<BinaryCrossEntropyBackward>)
# 370 tensor(0.0531, grad_fn=<BinaryCrossEntropyBackward>)
# 371 tensor(0.0530, grad_fn=<BinaryCrossEntropyBackward>)
# 372 tensor(0.0529, grad_fn=<BinaryCrossEntropyBackward>)
# 373 tensor(0.0528, grad_fn=<BinaryCrossEntropyBackward>)
# 374 tensor(0.0527, grad_fn=<BinaryCrossEntropyBackward>)
# 375 tensor(0.0526, grad_fn=<BinaryCrossEntropyBackward>)
# 376 tensor(0.0525, grad_fn=<BinaryCrossEntropyBackward>)
# 377 tensor(0.0524, grad_fn=<BinaryCrossEntropyBackward>)
# 378 tensor(0.0522, grad_fn=<BinaryCrossEntropyBackward>)
# 379 tensor(0.0521, grad_fn=<BinaryCrossEntropyBackward>)
# 380 tensor(0.0520, grad_fn=<BinaryCrossEntropyBackward>)
# 381 tensor(0.0519, grad_fn=<BinaryCrossEntropyBackward>)
# 382 tensor(0.0518, grad_fn=<BinaryCrossEntropyBackward>)
# 383 tensor(0.0517, grad_fn=<BinaryCrossEntropyBackward>)
# 384 tensor(0.0516, grad_fn=<BinaryCrossEntropyBackward>)
# 385 tensor(0.0515, grad_fn=<BinaryCrossEntropyBackward>)
# 386 tensor(0.0514, grad_fn=<BinaryCrossEntropyBackward>)
# 387 tensor(0.0513, grad_fn=<BinaryCrossEntropyBackward>)
# 388 tensor(0.0512, grad_fn=<BinaryCrossEntropyBackward>)
# 389 tensor(0.0511, grad_fn=<BinaryCrossEntropyBackward>)
# 390 tensor(0.0510, grad_fn=<BinaryCrossEntropyBackward>)
# 391 tensor(0.0509, grad_fn=<BinaryCrossEntropyBackward>)
# 392 tensor(0.0508, grad_fn=<BinaryCrossEntropyBackward>)
# 393 tensor(0.0507, grad_fn=<BinaryCrossEntropyBackward>)
# 394 tensor(0.0506, grad_fn=<BinaryCrossEntropyBackward>)
# 395 tensor(0.0505, grad_fn=<BinaryCrossEntropyBackward>)
# 396 tensor(0.0504, grad_fn=<BinaryCrossEntropyBackward>)
# 397 tensor(0.0503, grad_fn=<BinaryCrossEntropyBackward>)
# 398 tensor(0.0502, grad_fn=<BinaryCrossEntropyBackward>)
# 399 tensor(0.0501, grad_fn=<BinaryCrossEntropyBackward>)
# 400 tensor(0.0500, grad_fn=<BinaryCrossEntropyBackward>)
# 401 tensor(0.0499, grad_fn=<BinaryCrossEntropyBackward>)
# 402 tensor(0.0498, grad_fn=<BinaryCrossEntropyBackward>)
# 403 tensor(0.0497, grad_fn=<BinaryCrossEntropyBackward>)
# 404 tensor(0.0496, grad_fn=<BinaryCrossEntropyBackward>)
# 405 tensor(0.0495, grad_fn=<BinaryCrossEntropyBackward>)
# 406 tensor(0.0494, grad_fn=<BinaryCrossEntropyBackward>)
# 407 tensor(0.0493, grad_fn=<BinaryCrossEntropyBackward>)
# 408 tensor(0.0493, grad_fn=<BinaryCrossEntropyBackward>)
# 409 tensor(0.0492, grad_fn=<BinaryCrossEntropyBackward>)
# 410 tensor(0.0491, grad_fn=<BinaryCrossEntropyBackward>)
# 411 tensor(0.0490, grad_fn=<BinaryCrossEntropyBackward>)
# 412 tensor(0.0489, grad_fn=<BinaryCrossEntropyBackward>)
# 413 tensor(0.0488, grad_fn=<BinaryCrossEntropyBackward>)
# 414 tensor(0.0487, grad_fn=<BinaryCrossEntropyBackward>)
# 415 tensor(0.0486, grad_fn=<BinaryCrossEntropyBackward>)
# 416 tensor(0.0485, grad_fn=<BinaryCrossEntropyBackward>)
# 417 tensor(0.0484, grad_fn=<BinaryCrossEntropyBackward>)
# 418 tensor(0.0483, grad_fn=<BinaryCrossEntropyBackward>)
# 419 tensor(0.0483, grad_fn=<BinaryCrossEntropyBackward>)
# 420 tensor(0.0482, grad_fn=<BinaryCrossEntropyBackward>)
# 421 tensor(0.0481, grad_fn=<BinaryCrossEntropyBackward>)
# 422 tensor(0.0480, grad_fn=<BinaryCrossEntropyBackward>)
# 423 tensor(0.0479, grad_fn=<BinaryCrossEntropyBackward>)
# 424 tensor(0.0478, grad_fn=<BinaryCrossEntropyBackward>)
# 425 tensor(0.0477, grad_fn=<BinaryCrossEntropyBackward>)
# 426 tensor(0.0476, grad_fn=<BinaryCrossEntropyBackward>)
# 427 tensor(0.0476, grad_fn=<BinaryCrossEntropyBackward>)
# 428 tensor(0.0475, grad_fn=<BinaryCrossEntropyBackward>)
# 429 tensor(0.0474, grad_fn=<BinaryCrossEntropyBackward>)
# 430 tensor(0.0473, grad_fn=<BinaryCrossEntropyBackward>)
# 431 tensor(0.0472, grad_fn=<BinaryCrossEntropyBackward>)
# 432 tensor(0.0471, grad_fn=<BinaryCrossEntropyBackward>)
# 433 tensor(0.0471, grad_fn=<BinaryCrossEntropyBackward>)
# 434 tensor(0.0470, grad_fn=<BinaryCrossEntropyBackward>)
# 435 tensor(0.0469, grad_fn=<BinaryCrossEntropyBackward>)
# 436 tensor(0.0468, grad_fn=<BinaryCrossEntropyBackward>)
# 437 tensor(0.0467, grad_fn=<BinaryCrossEntropyBackward>)
# 438 tensor(0.0466, grad_fn=<BinaryCrossEntropyBackward>)
# 439 tensor(0.0466, grad_fn=<BinaryCrossEntropyBackward>)
# 440 tensor(0.0465, grad_fn=<BinaryCrossEntropyBackward>)
# 441 tensor(0.0464, grad_fn=<BinaryCrossEntropyBackward>)
# 442 tensor(0.0463, grad_fn=<BinaryCrossEntropyBackward>)
# 443 tensor(0.0462, grad_fn=<BinaryCrossEntropyBackward>)
# 444 tensor(0.0462, grad_fn=<BinaryCrossEntropyBackward>)
# 445 tensor(0.0461, grad_fn=<BinaryCrossEntropyBackward>)
# 446 tensor(0.0460, grad_fn=<BinaryCrossEntropyBackward>)
# 447 tensor(0.0459, grad_fn=<BinaryCrossEntropyBackward>)
# 448 tensor(0.0458, grad_fn=<BinaryCrossEntropyBackward>)
# 449 tensor(0.0458, grad_fn=<BinaryCrossEntropyBackward>)
# 450 tensor(0.0457, grad_fn=<BinaryCrossEntropyBackward>)
# 451 tensor(0.0456, grad_fn=<BinaryCrossEntropyBackward>)
# 452 tensor(0.0455, grad_fn=<BinaryCrossEntropyBackward>)
# 453 tensor(0.0455, grad_fn=<BinaryCrossEntropyBackward>)
# 454 tensor(0.0454, grad_fn=<BinaryCrossEntropyBackward>)
# 455 tensor(0.0453, grad_fn=<BinaryCrossEntropyBackward>)
# 456 tensor(0.0452, grad_fn=<BinaryCrossEntropyBackward>)
# 457 tensor(0.0451, grad_fn=<BinaryCrossEntropyBackward>)
# 458 tensor(0.0451, grad_fn=<BinaryCrossEntropyBackward>)
# 459 tensor(0.0450, grad_fn=<BinaryCrossEntropyBackward>)
# 460 tensor(0.0449, grad_fn=<BinaryCrossEntropyBackward>)
# 461 tensor(0.0448, grad_fn=<BinaryCrossEntropyBackward>)
# 462 tensor(0.0448, grad_fn=<BinaryCrossEntropyBackward>)
# 463 tensor(0.0447, grad_fn=<BinaryCrossEntropyBackward>)
# 464 tensor(0.0446, grad_fn=<BinaryCrossEntropyBackward>)
# 465 tensor(0.0446, grad_fn=<BinaryCrossEntropyBackward>)
# 466 tensor(0.0445, grad_fn=<BinaryCrossEntropyBackward>)
# 467 tensor(0.0444, grad_fn=<BinaryCrossEntropyBackward>)
# 468 tensor(0.0443, grad_fn=<BinaryCrossEntropyBackward>)
# 469 tensor(0.0443, grad_fn=<BinaryCrossEntropyBackward>)
# 470 tensor(0.0442, grad_fn=<BinaryCrossEntropyBackward>)
# 471 tensor(0.0441, grad_fn=<BinaryCrossEntropyBackward>)
# 472 tensor(0.0440, grad_fn=<BinaryCrossEntropyBackward>)
# 473 tensor(0.0440, grad_fn=<BinaryCrossEntropyBackward>)
# 474 tensor(0.0439, grad_fn=<BinaryCrossEntropyBackward>)
# 475 tensor(0.0438, grad_fn=<BinaryCrossEntropyBackward>)
# 476 tensor(0.0438, grad_fn=<BinaryCrossEntropyBackward>)
# 477 tensor(0.0437, grad_fn=<BinaryCrossEntropyBackward>)
# 478 tensor(0.0436, grad_fn=<BinaryCrossEntropyBackward>)
# 479 tensor(0.0436, grad_fn=<BinaryCrossEntropyBackward>)
# 480 tensor(0.0435, grad_fn=<BinaryCrossEntropyBackward>)
# 481 tensor(0.0434, grad_fn=<BinaryCrossEntropyBackward>)
# 482 tensor(0.0433, grad_fn=<BinaryCrossEntropyBackward>)
# 483 tensor(0.0433, grad_fn=<BinaryCrossEntropyBackward>)
# 484 tensor(0.0432, grad_fn=<BinaryCrossEntropyBackward>)
# 485 tensor(0.0431, grad_fn=<BinaryCrossEntropyBackward>)
# 486 tensor(0.0431, grad_fn=<BinaryCrossEntropyBackward>)
# 487 tensor(0.0430, grad_fn=<BinaryCrossEntropyBackward>)
# 488 tensor(0.0429, grad_fn=<BinaryCrossEntropyBackward>)
# 489 tensor(0.0429, grad_fn=<BinaryCrossEntropyBackward>)
# 490 tensor(0.0428, grad_fn=<BinaryCrossEntropyBackward>)
# 491 tensor(0.0427, grad_fn=<BinaryCrossEntropyBackward>)
# 492 tensor(0.0427, grad_fn=<BinaryCrossEntropyBackward>)
# 493 tensor(0.0426, grad_fn=<BinaryCrossEntropyBackward>)
# 494 tensor(0.0425, grad_fn=<BinaryCrossEntropyBackward>)
# 495 tensor(0.0425, grad_fn=<BinaryCrossEntropyBackward>)
# 496 tensor(0.0424, grad_fn=<BinaryCrossEntropyBackward>)
# 497 tensor(0.0423, grad_fn=<BinaryCrossEntropyBackward>)
# 498 tensor(0.0423, grad_fn=<BinaryCrossEntropyBackward>)
# 499 tensor(0.0422, grad_fn=<BinaryCrossEntropyBackward>)
